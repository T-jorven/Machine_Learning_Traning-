# %%
import pandas as pd

# %%
colour = ["magenta", "cyan", "yellow"]
series = pd.Series(colour)

# %%
series
# Out:
# 0    magenta
# 1       cyan
# 2     yellow
# dtype: object

# %%
car = ["BMW", "Candy", "Toyota"]
series2 = pd.Series(car)

# %%
series2
# Out:
# 0       BMW
# 1     Candy
# 2    Toyota
# dtype: object

# %%
series
# Out:
# 0    magenta
# 1       cyan
# 2     yellow
# dtype: object

# %%
df = pd.concat([series, series2], axis = 1)

# %%
df
# Out:
#          0       1
# 0  magenta     BMW
# 1     cyan   Candy
# 2   yellow  Toyota

# %%
df = pd.concat([series2, series], axis = 1)

# %%
df
# Out:
#         0        1
# 0     BMW  magenta
# 1   Candy     cyan
# 2  Toyota   yellow

# %%
df.to_csv("car-sales.csv", index = False)

# %%
df.dtypes
# Out:
# 0    object
# 1    object
# dtype: object

# %%
df.describe();

# %%
df
# Out:
#         0        1
# 0     BMW  magenta
# 1   Candy     cyan
# 2  Toyota   yellow

# %%
des = df.describe();
des
# Out:
#           0        1
# count     3        3
# unique    3        3
# top     BMW  magenta
# freq      1        1

# %%
inf = df.info();
inf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
num = pd.Series([56,35,247,98,24,2,8,25,76,15])
num
# Out:
# 0     56
# 1     35
# 2    247
# 3     98
# 4     24
# 5      2
# 6      8
# 7     25
# 8     76
# 9     15
# dtype: int64

# %%
mean = num.mean()
mean
# Out:
# np.float64(58.6)

# %%
suma = num.sum()
suma
# Out:
# np.int64(586)

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sq/zw6p8lcx51v8dcmxnrxdwhmc0000gn/T/ipykernel_24564/683132370.py in ?()
# ----> 1 df.length()
#
# ~/Desktop/sample_project/env/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
len(df)
# Out:
# 3

# %%
df.head(2)
# Out:
#        0        1
# 0    BMW  magenta
# 1  Candy     cyan

# %%
df.tail(2)
# Out:
#         0       1
# 1   Candy    cyan
# 2  Toyota  yellow

# %%
df.loc[2]
# Out:
# 0    Toyota
# 1    yellow
# Name: 2, dtype: object

# %%
df.iloc[1]
# Out:
# 0    Candy
# 1     cyan
# Name: 1, dtype: object

# %%
df2 = pd.read_csv("xportedcarsales.csv")

# %%
df2
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
df2['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df2['Odometer (KM)'].mean()
# Out:
# np.float64(78601.4)

# %%
df2[df2['Odometer (KM)'] > 100000]
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 0           0  Toyota  White         150043      4  $4,000.00
# 4           4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(df2['Make'], df2['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
df2.groupby('Make')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

df2['Odometer (KM)'].plot(kind='hist', bins=20, edgecolor='black')

plt.title('Odometer Distribution')
plt.xlabel('Odometer (KM)')
plt.ylabel('Frequency')
plt.show()

# %%
df2['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
# Create the histogram
df2['Odometer (KM)'].hist(bins=20, edgecolor='black')

# Add title and labels
plt.title('Odometer Distribution')
plt.xlabel('Odometer (KM)')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
# Create the histogram
df2['Price'].hist(bins=20, edgecolor='black')

# Add title and labels
plt.title('PriceDistribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
df2['Price'] = df2['Price'].replace({r'[^\w\s]': ''}, regex=True)

# %%
df2
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   400000
# 1           1   Honda    Red          87899      4   500000
# 2           2  Toyota   Blue          32549      3   700000
# 3           3     BMW  Black          11179      5  2200000
# 4           4  Nissan  White         213095      4   350000
# 5           5  Toyota  Green          99213      4   450000
# 6           6   Honda   Blue          45698      4   750000
# 7           7   Honda   Blue          54738      4   700000
# 8           8  Toyota  White          60000      4   625000
# 9           9  Nissan  White          31600      4   970000

# %%
# Create the histogram
df2['Price'].hist(bins=20, edgecolor='black')

# Add title and labels
plt.title('PriceDistribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
df2["Price"].dtype
# Out:
# dtype('O')

# %%
df2['Price'] = pd.to_numeric(df2['Price'], errors='coerce')

# %%
df2
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   400000
# 1           1   Honda    Red          87899      4   500000
# 2           2  Toyota   Blue          32549      3   700000
# 3           3     BMW  Black          11179      5  2200000
# 4           4  Nissan  White         213095      4   350000
# 5           5  Toyota  Green          99213      4   450000
# 6           6   Honda   Blue          45698      4   750000
# 7           7   Honda   Blue          54738      4   700000
# 8           8  Toyota  White          60000      4   625000
# 9           9  Nissan  White          31600      4   970000

# %%
# Create the histogram
df2['Price'].hist(bins=20, edgecolor='black')

# Add title and labels
plt.title('PriceDistribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
df2['Price'] = df2['Price'] / 100

# %%
df2
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   4000.0
# 1           1   Honda    Red          87899      4   5000.0
# 2           2  Toyota   Blue          32549      3   7000.0
# 3           3     BMW  Black          11179      5  22000.0
# 4           4  Nissan  White         213095      4   3500.0
# 5           5  Toyota  Green          99213      4   4500.0
# 6           6   Honda   Blue          45698      4   7500.0
# 7           7   Honda   Blue          54738      4   7000.0
# 8           8  Toyota  White          60000      4   6250.0
# 9           9  Nissan  White          31600      4   9700.0

# %%
df2['Make'] = df2['Make'].str.lower()

# %%
df2
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  toyota  White         150043      4   4000.0
# 1           1   honda    Red          87899      4   5000.0
# 2           2  toyota   Blue          32549      3   7000.0
# 3           3     bmw  Black          11179      5  22000.0
# 4           4  nissan  White         213095      4   3500.0
# 5           5  toyota  Green          99213      4   4500.0
# 6           6   honda   Blue          45698      4   7500.0
# 7           7   honda   Blue          54738      4   7000.0
# 8           8  toyota  White          60000      4   6250.0
# 9           9  nissan  White          31600      4   9700.0

# %%
df3 = pd.read_csv("car-sales-missing-data.csv")
df3
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill missing values with the mean of the column
df3['Odometer'].fillna(df3['Odometer'].mean(), inplace=True)

df3
# Out:
# /var/folders/sq/zw6p8lcx51v8dcmxnrxdwhmc0000gn/T/ipykernel_24564/4281496270.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Odometer'].fillna(df3['Odometer'].mean(), inplace=True)
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   32549.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   99213.0    4.0   $4,500
# ...

# %%
df3['Doors'].fillna(df3['Doors'].mean(), inplace=True)

df3
# Out:
# /var/folders/sq/zw6p8lcx51v8dcmxnrxdwhmc0000gn/T/ipykernel_24564/656194199.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Doors'].fillna(df3['Doors'].mean(), inplace=True)
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0    NaN
# 1   Honda    Red   87899.0    4.0    NaN
# 2  Toyota   Blue   32549.0    3.0    NaN
# 3     BMW  Black   11179.0    5.0    NaN
# 4  Nissan  White  213095.0    4.0    NaN
# 5  Toyota  Green   99213.0    4.0    NaN
# ...

# %%
# List of values to replace NaN values in the 'Price' column
fill_values = [1000, 5000, 4568, 2468, 3466, 5768, 4452, 9355, 2245, 3009]

# Fill NaN values in the 'Price' column with corresponding values from the list
df3['Price'] = df3['Price'].fillna(pd.Series(fill_values))

df3
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0      1
# 1   Honda    Red   87899.0    4.0      1
# 2  Toyota   Blue   32549.0    3.0      1
# 3     BMW  Black   11179.0    5.0      1
# 4  Nissan  White  213095.0    4.0      1
# 5  Toyota  Green   99213.0    4.0      1
# 6   Honda    NaN   45698.0    4.0      1
# 7   Honda   Blue   54738.0    4.0      1
# 8  Toyota  White   60000.0    4.0      1
# 9     NaN  White   31600.0    4.0      1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('xportedcarsales.csv')

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
df['Seats'] = 5

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price  Seats
# 0           0  Toyota  White         150043      4   $4,000.00      5
# 1           1   Honda    Red          87899      4   $5,000.00      5
# 2           2  Toyota   Blue          32549      3   $7,000.00      5
# 3           3     BMW  Black          11179      5  $22,000.00      5
# 4           4  Nissan  White         213095      4   $3,500.00      5
# 5           5  Toyota  Green          99213      4   $4,500.00      5
# 6           6   Honda   Blue          45698      4   $7,500.00      5
# 7           7   Honda   Blue          54738      4   $7,000.00      5
# 8           8  Toyota  White          60000      4   $6,250.00      5
# 9           9  Nissan  White          31600      4   $9,700.00      5

# %%
df['Engine Size'] = math.random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Engine Size'] = math.random()
#
# NameError: name 'math' is not defined

# %%
import random

# %%
df['Engine Size'] = [random.uniform(1.3, 4.5) for _ in range(len(df))]

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0           0  Toyota  White         150043      4   $4,000.00      5
# 1           1   Honda    Red          87899      4   $5,000.00      5
# 2           2  Toyota   Blue          32549      3   $7,000.00      5
# 3           3     BMW  Black          11179      5  $22,000.00      5
# 4           4  Nissan  White         213095      4   $3,500.00      5
# 5           5  Toyota  Green          99213      4   $4,500.00      5
# 6           6   Honda   Blue          45698      4   $7,500.00      5
# 7           7   Honda   Blue          54738      4   $7,000.00      5
# 8           8  Toyota  White          60000      4   $6,250.00      5
# 9           9  Nissan  White          31600      4   $9,700.00      5
#
#    Engine Size
# 0     4.499758
# 1     2.137808
# 2     2.053854
# 3     1.994936
# 4     1.773228
# 5     2.308345
# 6     2.761717
# 7     3.924778
# 8     4.262295
# 9     1.564060

# %%
df['Price'] = df['Price'].replace({r'[^\w\s]': ''}, regex=True)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Price per KM'] = df['Price'] / df['Odometer (KM)']

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  Toyota  White         150043      4   400000      5
# 1           1   Honda    Red          87899      4   500000      5
# 2           2  Toyota   Blue          32549      3   700000      5
# 3           3     BMW  Black          11179      5  2200000      5
# 4           4  Nissan  White         213095      4   350000      5
# 5           5  Toyota  Green          99213      4   450000      5
# 6           6   Honda   Blue          45698      4   750000      5
# 7           7   Honda   Blue          54738      4   700000      5
# 8           8  Toyota  White          60000      4   625000      5
# 9           9  Nissan  White          31600      4   970000      5
#
#    Engine Size  Price per KM
# 0     4.499758      2.665902
# 1     2.137808      5.688347
# 2     2.053854     21.506037
# 3     1.994936    196.797567
# 4     1.773228      1.642460
# 5     2.308345      4.535696
# ...

# %%
df['Price'] = df['Price'] / 100
df['Price per KM'] = df['Price per KM'] / 100

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  Toyota  White         150043      4   4000.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 2           2  Toyota   Blue          32549      3   7000.0      5
# 3           3     BMW  Black          11179      5  22000.0      5
# 4           4  Nissan  White         213095      4   3500.0      5
# 5           5  Toyota  Green          99213      4   4500.0      5
# 6           6   Honda   Blue          45698      4   7500.0      5
# 7           7   Honda   Blue          54738      4   7000.0      5
# 8           8  Toyota  White          60000      4   6250.0      5
# 9           9  Nissan  White          31600      4   9700.0      5
#
#    Engine Size  Price per KM
# 0     4.499758      0.026659
# 1     2.137808      0.056883
# 2     2.053854      0.215060
# 3     1.994936      1.967976
# 4     1.773228      0.016425
# 5     2.308345      0.045357
# ...

# %%
df.drop(columns=['Price per KM'], inplace=True)

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  Toyota  White         150043      4   4000.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 2           2  Toyota   Blue          32549      3   7000.0      5
# 3           3     BMW  Black          11179      5  22000.0      5
# 4           4  Nissan  White         213095      4   3500.0      5
# 5           5  Toyota  Green          99213      4   4500.0      5
# 6           6   Honda   Blue          45698      4   7500.0      5
# 7           7   Honda   Blue          54738      4   7000.0      5
# 8           8  Toyota  White          60000      4   6250.0      5
# 9           9  Nissan  White          31600      4   9700.0      5
#
#    Engine Size
# 0     4.499758
# 1     2.137808
# 2     2.053854
# 3     1.994936
# 4     1.773228
# 5     2.308345
# 6     2.761717
# 7     3.924778
# 8     4.262295
# 9     1.564060

# %%
sdf = df.sample(frac=1, random_state=42)

# %%
df
sdf
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 8           8  Toyota  White          60000      4   6250.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 5           5  Toyota  Green          99213      4   4500.0      5
# 0           0  Toyota  White         150043      4   4000.0      5
# 7           7   Honda   Blue          54738      4   7000.0      5
# 2           2  Toyota   Blue          32549      3   7000.0      5
# 9           9  Nissan  White          31600      4   9700.0      5
# 4           4  Nissan  White         213095      4   3500.0      5
# 3           3     BMW  Black          11179      5  22000.0      5
# 6           6   Honda   Blue          45698      4   7500.0      5
#
#    Engine Size
# 8     4.262295
# 1     2.137808
# 5     2.308345
# 0     4.499758
# 7     3.924778
# 2     2.053854
# 9     1.564060
# 4     1.773228
# 3     1.994936
# 6     2.761717

# %%
df
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  Toyota  White         150043      4   4000.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 2           2  Toyota   Blue          32549      3   7000.0      5
# 3           3     BMW  Black          11179      5  22000.0      5
# 4           4  Nissan  White         213095      4   3500.0      5
# 5           5  Toyota  Green          99213      4   4500.0      5
# 6           6   Honda   Blue          45698      4   7500.0      5
# 7           7   Honda   Blue          54738      4   7000.0      5
# 8           8  Toyota  White          60000      4   6250.0      5
# 9           9  Nissan  White          31600      4   9700.0      5
#
#    Engine Size
# 0     4.499758
# 1     2.137808
# 2     2.053854
# 3     1.994936
# 4     1.773228
# 5     2.308345
# 6     2.761717
# 7     3.924778
# 8     4.262295
# 9     1.564060

# %%
sdf
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 8           8  Toyota  White          60000      4   6250.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 5           5  Toyota  Green          99213      4   4500.0      5
# 0           0  Toyota  White         150043      4   4000.0      5
# 7           7   Honda   Blue          54738      4   7000.0      5
# 2           2  Toyota   Blue          32549      3   7000.0      5
# 9           9  Nissan  White          31600      4   9700.0      5
# 4           4  Nissan  White         213095      4   3500.0      5
# 3           3     BMW  Black          11179      5  22000.0      5
# 6           6   Honda   Blue          45698      4   7500.0      5
#
#    Engine Size
# 8     4.262295
# 1     2.137808
# 5     2.308345
# 0     4.499758
# 7     3.924778
# 2     2.053854
# 9     1.564060
# 4     1.773228
# 3     1.994936
# 6     2.761717

# %%
sdf.reset_index(drop=True, inplace=True);

# %%
sdf
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           8  Toyota  White          60000      4   6250.0      5
# 1           1   Honda    Red          87899      4   5000.0      5
# 2           5  Toyota  Green          99213      4   4500.0      5
# 3           0  Toyota  White         150043      4   4000.0      5
# 4           7   Honda   Blue          54738      4   7000.0      5
# 5           2  Toyota   Blue          32549      3   7000.0      5
# 6           9  Nissan  White          31600      4   9700.0      5
# 7           4  Nissan  White         213095      4   3500.0      5
# 8           3     BMW  Black          11179      5  22000.0      5
# 9           6   Honda   Blue          45698      4   7500.0      5
#
#    Engine Size
# 0     4.262295
# 1     2.137808
# 2     2.308345
# 3     4.499758
# 4     3.924778
# 5     2.053854
# 6     1.564060
# 7     1.773228
# 8     1.994936
# 9     2.761717

# %%
sdf['Odometer (KM)'] = sdf['Odometer (KM)'].apply(lambda x: x * 0.621371 if pd.notna(x) else x)

# %%
sdf
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           8  Toyota  White   37282.260000      4   6250.0      5
# 1           1   Honda    Red   54617.889529      4   5000.0      5
# 2           5  Toyota  Green   61648.081023      4   4500.0      5
# 3           0  Toyota  White   93232.368953      4   4000.0      5
# 4           7   Honda   Blue   34012.605798      4   7000.0      5
# 5           2  Toyota   Blue   20225.004679      3   7000.0      5
# 6           9  Nissan  White   19635.323600      4   9700.0      5
# 7           4  Nissan  White  132411.053245      4   3500.0      5
# 8           3     BMW  Black    6946.306409      5  22000.0      5
# 9           6   Honda   Blue   28395.411958      4   7500.0      5
#
#    Engine Size
# 0     4.262295
# 1     2.137808
# 2     2.308345
# 3     4.499758
# 4     3.924778
# 5     2.053854
# 6     1.564060
# 7     1.773228
# 8     1.994936
# 9     2.761717

# %%
sdf['Odometer (KM)'] = sdf['Odometer (KM)'] / 100
sdf.rename(columns={'Odometer (KM)': 'Odometer (Miles)'})
# Out:
#    Unnamed: 0    Make Colour  Odometer (Miles)  Doors    Price  Seats  \
# 0           8  Toyota  White        372.822600      4   6250.0      5
# 1           1   Honda    Red        546.178895      4   5000.0      5
# 2           5  Toyota  Green        616.480810      4   4500.0      5
# 3           0  Toyota  White        932.323690      4   4000.0      5
# 4           7   Honda   Blue        340.126058      4   7000.0      5
# 5           2  Toyota   Blue        202.250047      3   7000.0      5
# 6           9  Nissan  White        196.353236      4   9700.0      5
# 7           4  Nissan  White       1324.110532      4   3500.0      5
# 8           3     BMW  Black         69.463064      5  22000.0      5
# 9           6   Honda   Blue        283.954120      4   7500.0      5
#
#    Engine Size
# 0     4.262295
# 1     2.137808
# 2     2.308345
# 3     4.499758
# 4     3.924778
# 5     2.053854
# 6     1.564060
# 7     1.773228
# 8     1.994936
# 9     2.761717
